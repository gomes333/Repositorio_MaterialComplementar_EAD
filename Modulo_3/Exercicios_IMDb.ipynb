# %% [markdown]
# # 🎬 Jupyter Notebook: Explorando o Top 250 do IMDb
#
# **Bem-vindo(a)!** Neste notebook, vamos explorar um banco de dados com os 250 filmes mais bem avaliados do IMDb.
# O objetivo é usar o Pandas para "fazer perguntas" para a tabela e descobrir curiosidades sobre cinema.

# %%
# Célula 0: Configuração inicial (Rode isso primeiro!)
import pandas as pd
import matplotlib.pyplot as plt

# Carregando os dados (Certifique-se de que o arquivo .csv está na mesma pasta)
df = pd.read_csv("filmes.csv")
print("Deu certo")
# Out:
# Deu certo

# %% [markdown]
# ---
# ### 🟢 Nível 1: Conhecendo a Tabela (O Básico)
#
# Antes de qualquer coisa, precisamos ver como os dados estão organizados.
#
# **Exercício 1:**
# Mostre as **5 primeiras linhas** da tabela para ver como ela é.

# %%
# Seu código aqui
df.head(5)
# Out:
#    Rank                     Title  Year  Rating Duration   Genre  \
# 0     1  The Shawshank Redemption  1994     9.3   2h 22m   Drama
# 1     2             The Godfather  1972     9.2   2h 55m   Crime
# 2     3           The Dark Knight  2008     9.1   2h 32m  Action
# 3     4     The Godfather Part II  1974     9.0   3h 22m   Crime
# 4     5              12 Angry Men  1957     9.0   1h 36m   Drama
#
#                                 IMDb URL  \
# 0  https://www.imdb.com/title/tt0111161/
# 1  https://www.imdb.com/title/tt0068646/
# 2  https://www.imdb.com/title/tt0468569/
# 3  https://www.imdb.com/title/tt0071562/
# 4  https://www.imdb.com/title/tt0050083/
#
#                                            Image URL
# 0  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 1  https://m.media-amazon.com/images/M/MV5BNGEwYj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMDIxMz...
# 4  https://m.media-amazon.com/images/M/MV5BYjE4Nz...

# %% [markdown]
# **Exercício 2:**
# Agora, mostre as **5 últimas linhas** da tabela. Quem são os filmes que estão no finalzinho do Top 250?

# %%
# Seu código aqui
df.tail()
# Out:
#      Rank                Title  Year  Rating Duration     Genre  \
# 245   246  The Grapes of Wrath  1940     8.1    2h 9m     Drama
# 246   247   To Be or Not to Be  1942     8.1   1h 39m    Comedy
# 247   248   Gangs of Wasseypur  2012     8.2   5h 21m     Crime
# 248   249             Drishyam  2015     8.2   2h 43m  Thriller
# 249   250             The Help  2011     8.1   2h 26m     Drama
#
#                                   IMDb URL  \
# 245  https://www.imdb.com/title/tt0032551/
# 246  https://www.imdb.com/title/tt0035446/
# 247  https://www.imdb.com/title/tt1954470/
# 248  https://www.imdb.com/title/tt4430212/
# 249  https://www.imdb.com/title/tt1454029/
#
#                                              Image URL
# 245  https://m.media-amazon.com/images/M/MV5BZDgzZj...
# 246  https://m.media-amazon.com/images/M/MV5BMTA5OT...
# 247  https://m.media-amazon.com/images/M/MV5BMTc5Nj...
# 248  https://m.media-amazon.com/images/M/MV5BM2NmMG...
# 249  https://m.media-amazon.com/images/M/MV5BMTM5OT...

# %% [markdown]
# **Exercício 3:**
# Quantas linhas e quantas colunas tem o nosso banco de dados?
#
# *Dica: use o `.shape`*

# %%
# Seu código aqui
df.shape
# Out:
# (250, 8)

# %% [markdown]
# ---
# ### 🟡 Nível 2: Filtrando e Ordenando (Procurando Joias)
#
# A tabela já vem ordenada pelo Rank (posição), mas podemos organizar de outras formas.
#
# **Exercício 4:**
# Mostre apenas os filmes que têm nota (`Rating`) **maior ou igual a 9.0**. Quantos filmes conseguiram essa façanha?

# %%
# Seu código aqui
df[df["Rating"]>=9.0]
# Out:
#    Rank                                          Title  Year  Rating Duration  \
# 0     1                       The Shawshank Redemption  1994     9.3   2h 22m
# 1     2                                  The Godfather  1972     9.2   2h 55m
# 2     3                                The Dark Knight  2008     9.1   2h 32m
# 3     4                          The Godfather Part II  1974     9.0   3h 22m
# 4     5                                   12 Angry Men  1957     9.0   1h 36m
# 5     6  The Lord of the Rings: The Return of the King  2003     9.0   3h 21m
# 6     7                               Schindler's List  1993     9.0   3h 15m
#
#        Genre                               IMDb URL  \
# 0      Drama  https://www.imdb.com/title/tt0111161/
# 1      Crime  https://www.imdb.com/title/tt0068646/
# 2     Action  https://www.imdb.com/title/tt0468569/
# 3      Crime  https://www.imdb.com/title/tt0071562/
# 4      Drama  https://www.imdb.com/title/tt0050083/
# 5  Adventure  https://www.imdb.com/title/tt0167260/
# 6  Biography  https://www.imdb.com/title/tt0108052/
#
#                                            Image URL
# 0  https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 1  https://m.media-amazon.com/images/M/MV5BNGEwYj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMDIxMz...
# 4  https://m.media-amazon.com/images/M/MV5BYjE4Nz...
# 5  https://m.media-amazon.com/images/M/MV5BMTZkMj...
# 6  https://m.media-amazon.com/images/M/MV5BNjM1ZD...

# %% [markdown]
# **Exercício 5:**
# Vamos ver os filmes mais **antigos** da lista. Ordene a tabela pelo ano (`Year`) de forma crescente (do mais antigo para o mais novo) e mostre apenas as 5 primeiras linhas do resultado.

# %%
# Seu código aqui
df.sort_values(by='Year').head()
# Out:
#      Rank          Title  Year  Rating Duration   Genre  \
# 138   139        The Kid  1921     8.2    1h 8m  Comedy
# 205   206   Sherlock Jr.  1924     8.1      45m  Comedy
# 204   205  The Gold Rush  1925     8.1   1h 35m  Comedy
# 209   210    The General  1926     8.1   1h 18m  Comedy
# 118   119     Metropolis  1927     8.3   2h 33m  Sci-Fi
#
#                                   IMDb URL  \
# 138  https://www.imdb.com/title/tt0012349/
# 205  https://www.imdb.com/title/tt0015324/
# 204  https://www.imdb.com/title/tt0015864/
# 209  https://www.imdb.com/title/tt0017925/
# 118  https://www.imdb.com/title/tt0017136/
#
#                                              Image URL
# 138  https://m.media-amazon.com/images/M/MV5BNjkxMz...
# 205  https://m.media-amazon.com/images/M/MV5BMjQzM2...
# 204  https://m.media-amazon.com/images/M/MV5BNGU1Nj...
# 209  https://m.media-amazon.com/images/M/MV5BMTVhM2...
# 118  https://m.media-amazon.com/images/M/MV5BMjhjMG...

# %% [markdown]
# **Exercício 6:**
# Agora o contrário: quais são os filmes mais **recentes** da lista? Ordene pelo ano de forma decrescente e mostre os 5 primeiros.
#
# *Dica: Adicione o parâmetro `ascending=False` no sort_values*

# %%
# Seu código aqui
df.sort_values(by='Year',ascending=False).head()
# Out:
#      Rank                                              Title  Year  Rating  \
# 171   172  Demon Slayer: Kimetsu no Yaiba- The Movie - In...  2025     8.5
# 127   128                           One Battle After Another  2025     8.3
# 219   220                                           Maharaja  2024     8.3
# 179   180                                     The Wild Robot  2024     8.2
# 57     58                                     Dune: Part Two  2024     8.4
#
#     Duration      Genre                                IMDb URL  \
# 171   2h 35m  Animation  https://www.imdb.com/title/tt32820897/
# 127   2h 41m     Action  https://www.imdb.com/title/tt30144839/
# 219   2h 21m     Action  https://www.imdb.com/title/tt26548265/
# 179   1h 42m  Animation  https://www.imdb.com/title/tt29623480/
# 57    2h 46m     Sci-Fi  https://www.imdb.com/title/tt15239678/
#
#                                              Image URL
# 171  https://m.media-amazon.com/images/M/MV5BOGQ3YW...
# 127  https://m.media-amazon.com/images/M/MV5BMzBkZm...
# 219  https://m.media-amazon.com/images/M/MV5BOTFlMT...
# 179  https://m.media-amazon.com/images/M/MV5BZWNiZj...
# 57   https://m.media-amazon.com/images/M/MV5BNTc0Ym...

# %% [markdown]
# ---
# ### 🟠 Nível 3: Curiosidades e Estatísticas Simples
#
# Vamos usar funções matemáticas básicas para entender a lista.
#
# **Exercício 7:**
# Qual é a **média das notas** (`Rating`) de todos os 250 filmes? E qual é a média dos anos de lançamento?
#
# *Dica: Use o comando `.mean()` na coluna desejada.*

# %%
# Seu código aqui
df["Rating"].mean()
df["Year"].mean()
# Out:
# np.float64(1988.732)

# %% [markdown]
# **Exercício 8:**
# Quem é o filme com a **maior duração** da lista? E qual é essa duração?
# *(Dica: Como a duração está em texto, ex: '2h 22m', você pode ordenar a coluna 'Duration' e ver qual fica no topo ou no final).*

# %%
# Seu código aqui
df.sort_values(by="Duration",ascending=False).head(1)
# Out:
#      Rank              Title  Year  Rating Duration  Genre  \
# 159   160  The Best of Youth  2003     8.4   6h 14m  Drama
#
#                                   IMDb URL  \
# 159  https://www.imdb.com/title/tt0346336/
#
#                                              Image URL
# 159  https://m.media-amazon.com/images/M/MV5BYzcxMT...

# %% [markdown]
# ---
# ### 🔴 Nível 4: Um pouco de Visualização (Gráficos)
#
# Uma imagem vale mais que mil palavras. Vamos criar gráficos simples.
#
# **Exercício 9:**
# Crie um **gráfico de barras** mostrando a contagem de filmes por ano (`Year`).
# *Pergunta:* Teve algum ano que teve muitos filmes na lista?
#
# *Dica: Use `df['Year'].value_counts().head(10).plot(kind='bar')`*

# %%
# Seu código aqui
df["Year"].value_counts().head(10).plot(kind='bar',title='Quantidade de Filmes Por Ano')
# Out:
# <Axes: title={'center': 'Quantidade de Filmes Por Ano'}, xlabel='Year'>

# %% [markdown]
# **Exercício 10:**
# Crie um **histograma** para ver como as notas estão distribuídas. A maioria dos filmes tem nota 8, 8.5 ou 9?
#
# *Dica: Use `df['Rating'].plot(kind='hist', bins=20)`*

# %%
# Seu código aqui
df['Rating'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>
